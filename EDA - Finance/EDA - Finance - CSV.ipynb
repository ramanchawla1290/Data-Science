# %% [markdown]
# # Exploratory Data Analysis - Finance
#
# This data project focuses on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
#
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.
#
# ___
#
# ## Data : CSV files
#
# <big>The data to be analyzed is in the form of <b>CSV files (included)</b></big>.
# - <code><b>bank_stocks_data.csv</b></code> : Data of Stocks from 2008 to 2015
# - <code><b>ticker_info.csv</b></code> : Ticker Information of Stocks under Consideration
#
# <br><br>
# <big>We will analyze the stocks of the following banks</big>:
#
# - Bank of America (ticker : BAC)
# - CitiGroup (ticker : C)
# - Goldman Sachs (ticker : GS)
# - JPMorgan Chase (ticker : JPM)
# - Morgan Stanley (ticker : MS)
# - Wells Fargo  Co. (ticker : WFC)

# %%
import datetime as dt
import numpy as np
import pandas as pd

# %%
ticker_data = pd.read_csv('./ticker_info.csv', index_col='ticker')

ticker_data
# Out:
#                    name
# ticker
# BAC     Bank of America
# C             CitiGroup
# GS        Goldman Sachs
# JPM     JP Morgan Chase
# MS       Morgan Stanley
# WFC         Wells Fargo

# %%
tickers = ticker_data.index.to_list()

tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
stocks = ticker_data['name'].to_list()

stocks
# Out:
# ['Bank of America',
#  'CitiGroup',
#  'Goldman Sachs',
#  'JP Morgan Chase',
#  'Morgan Stanley',
#  'Wells Fargo']

# %%
# Bank Stock Data

bank_stocks = pd.read_csv('./bank_stocks_data.csv').set_index(['Date', 'ticker'])

bank_stocks.head(len(tickers))
# Out:
#                      High     Low    Open   Close      Volume  Adj Close
# Date       ticker
# 2006-01-03 BAC      47.18   46.15   46.92   47.08  16296700.0      34.28
#            WFC      31.98   31.19   31.60   31.90  11016400.0      20.52
#            MS       58.49   56.74   57.17   58.31   5377000.0      36.36
#            JPM      40.36   39.30   39.83   40.19  12838600.0      26.66
#            GS      129.44  124.23  126.70  128.87   6188700.0     104.92
#            C       493.80  481.10  490.00  492.90   1537600.0     370.93

# %% [markdown]
# ## Basic Questions
# ___

# %% [markdown]
# ### What is the maximum and minimum <code>Close</code> price for each bank's stock throughout the time period?

# %% [markdown]
# ### Values

# %%
# Maximum Value for each stock during the period 

bank_stocks.groupby('ticker')['Close'].max()
# Out:
# ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# Name: Close, dtype: float64

# %%
# Minimum Value for each stock during the period

bank_stocks.groupby('ticker')['Close'].min()
# Out:
# ticker
# BAC     3.14
# C      10.20
# GS     52.00
# JPM    15.90
# MS      9.20
# WFC     8.12
# Name: Close, dtype: float64

# %% [markdown]
# ### Dates

# %%
df = bank_stocks.xs(key='Close', axis=1).unstack()

df.head()
# Out:
# ticker        BAC      C      GS    JPM     MS    WFC
# Date
# 2006-01-03  47.08  492.9  128.87  40.19  58.31  31.90
# 2006-01-04  46.58  483.8  127.09  39.62  58.35  31.53
# 2006-01-05  46.64  486.2  127.04  39.74  58.51  31.50
# 2006-01-06  46.57  486.2  128.84  40.02  58.57  31.68
# 2006-01-09  46.60  483.9  130.39  40.67  59.19  31.67

# %%
# Dates of Maximum Value for each stock during the period 

df.idxmax()
# Out:
# ticker
# BAC    2006-11-16
# C      2006-12-27
# GS     2007-10-31
# JPM    2015-07-22
# MS     2007-06-14
# WFC    2015-07-22
# dtype: object

# %%
# Dates of Minimum Value for each stock during the period 

df.idxmin()
# Out:
# ticker
# BAC    2009-03-06
# C      2009-03-05
# GS     2008-11-20
# JPM    2009-03-09
# MS     2008-11-20
# WFC    2009-03-05
# dtype: object

# %% [markdown]
# ### Values With Dates

# %%
# Maximum Value : with Date

df_ = None

for tick in tickers:
    df_temp = df[df[tick] == df[tick].max()][[tick]]
    
    if df_ is None:
        df_ = df_temp
    else:
        df_ = pd.concat([df_, df_temp])

df_.stack()
# Out:
# Date        ticker
# 2006-11-16  BAC        54.90
# 2006-11-20  BAC        54.90
# 2006-12-27  C         564.10
# 2007-10-31  GS        247.92
# 2015-07-22  JPM        70.08
# 2007-06-14  MS         89.30
# 2015-07-22  WFC        58.52
# dtype: float64

# %%
# Maximum Value : with Date

df_ = None

for tick in tickers:
    df_temp = df[df[tick] == df[tick].min()][[tick]]
    
    if df_ is None:
        df_ = df_temp
    else:
        df_ = pd.concat([df_, df_temp])

df_.stack()
# Out:
# Date        ticker
# 2009-03-06  BAC        3.14
# 2009-03-05  C         10.20
# 2008-11-20  GS        52.00
# 2009-03-09  JPM       15.90
# 2008-11-20  MS         9.20
# 2009-03-05  WFC        8.12
# dtype: float64

# %% [markdown]
# ## Plotting Closing values over time period
# ___

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('ggplot')
sns.set_context('talk')

# %%
import cufflinks as cfl

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

cfl.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.3.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.3.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Interactive Plot

df.iplot()
# Out:
# <div>                            <div id="f3ccd26f-a490-4230-9d30-749a8c94e47c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("f3ccd26f-a490-4230-9d30-749a8c94e47c")) {                    Plotly.newPlot(                        "f3ccd26f-a490-4230-9d30-749a8c94e47c",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"BAC","text":"","type":"scatter","x":["2006-01-03","2006-01-04","2006-01-05","2006-01-06","2006-01-09","2006-01-10","2006-01-11","2006-01-12","2006-01-13","2006-01-17","2006-01-18","2006-01-19","2006-01-20","2006-01-23","2006-01-24","2006-01-25","2006-01-26","2006-01-27","2006-01-30","2006-01-31","2006-02-01","2006-02-02","2006-02-03","2006-02-06","2006-02-07","2006-02-08","2006-02-09","2006-02-10","2006-02-13","2006-02-14","2006-02-15","2006-02-16","2006-02-17","2006-02-21","2006-02-22","2006-02-23","2006-02-24","2006-02-27","2006-02-28","2006-03-01","2006-03-02","2006-03-03","2006-03-06","2006-03-07","2006-03-08","2006-03-09","2006-03-10","2006-03-13","2006-03-14","2006-03-15","2006-03-16","2006-03-17","2006-03-20","2006-03-21","2006-03-22","2006-03-23","2006-03-24","2006-03-27","2006-03-28","2006-03-29","2006-03-30","2006-03-31","2006-04-03","2006-04-04","2006-04-05","2006-04-06","2006-04-07","2006-04-10","2006-04-11","2006-04-12","2006-04-13","2006-04-17","2006-04-18","2006-04-19","2006-

# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Static Plot 2

plt.figure(figsize=(15,8))

for tick in tickers:
      df[tick].plot(label=tick)

plt.ylabel('Closing Value')
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## Returns for each stock over time period
#
# We will calculate the percentage change on the daily <code>Close</code> value

# %%
returns = df.pct_change()

returns.head()
# Out:
# ticker           BAC         C        GS       JPM        MS       WFC
# Date
# 2006-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2006-01-04 -0.010620 -0.018462 -0.013812 -0.014183  0.000686 -0.011599
# 2006-01-05  0.001288  0.004961 -0.000393  0.003029  0.002742 -0.000951
# 2006-01-06 -0.001501  0.000000  0.014169  0.007046  0.001025  0.005714
# 2006-01-09  0.000644 -0.004731  0.012030  0.016242  0.010586 -0.000316

# %%
plt.style.use('seaborn')
sns.set_context('notebook')

g = sns.PairGrid(returns)

g.map_diag(sns.histplot, bins=10)
g.map_upper(sns.scatterplot)
g.map_lower(sns.scatterplot)

# %% [markdown]
# ### What was Highest Gain and Highest Loss for each bank stock in a single day during the time period?
#
# (in percentage)

# %% [markdown]
# ### Values

# %%
# Highest Gain in a single day

returns.max()
# Out:
# ticker
# BAC    0.352691
# C      0.578249
# GS     0.264678
# JPM    0.250967
# MS     0.869835
# WFC    0.327645
# dtype: float64

# %%
# Highest Loss in a single day

returns.min()
# Out:
# ticker
# BAC   -0.289694
# C     -0.390244
# GS    -0.189596
# JPM   -0.207274
# MS    -0.258929
# WFC   -0.238223
# dtype: float64

# %% [markdown]
# ## Dates

# %%
# Dates for Highest Gain in a single day

returns.idxmax()
# Out:
# ticker
# BAC    2009-04-09
# C      2008-11-24
# GS     2008-11-24
# JPM    2009-01-21
# MS     2008-10-13
# WFC    2008-07-16
# dtype: object

# %%
# Dates for Highest Loss in a single day

returns.idxmin()
# Out:
# ticker
# BAC    2009-01-20
# C      2009-02-27
# GS     2009-01-20
# JPM    2009-01-20
# MS     2008-10-09
# WFC    2009-01-20
# dtype: object

# %% [markdown]
# ### Values with Dates

# %%
# Highest Gain in a single day : With Date

df_ = None

for tick in tickers:
    df_temp = returns[returns[tick] == returns[tick].max()][[tick]]

    if df_ is None:
        df_ = df_temp
    else:
        df_ = pd.concat([df_, df_temp])

df_ = df_.stack().reset_index().set_index('ticker')

df_.columns = ['Date', 'Highest Gain']

df_[['Highest Gain', 'Date']]
# Out:
#         Highest Gain        Date
# ticker
# BAC         0.352691  2009-04-09
# C           0.578249  2008-11-24
# GS          0.264678  2008-11-24
# JPM         0.250967  2009-01-21
# MS          0.869835  2008-10-13
# WFC         0.327645  2008-07-16

# %%
# Highest Loss in a single day : With Date

df_ = None

for tick in tickers:
    df_temp = returns[returns[tick] == returns[tick].min()][[tick]]

    if df_ is None:
        df_ = df_temp
    else:
        df_ = pd.concat([df_, df_temp])

df_ = df_.stack().reset_index().set_index('ticker')

df_.columns = ['Date', 'Highest Loss']

df_[['Highest Loss', 'Date']]
# Out:
#         Highest Loss        Date
# ticker
# BAC        -0.289694  2009-01-20
# C          -0.390244  2009-02-27
# GS         -0.189596  2009-01-20
# JPM        -0.207274  2009-01-20
# MS         -0.258929  2008-10-09
# WFC        -0.238223  2009-01-20

# %% [markdown]
# ### What was riskiest and safest bank stock throughout the time period?
#
# Riskiest means stock with highest <b>standard deviation</b>.

# %%
df_risk = returns.std()

df_risk
# Out:
# ticker
# BAC    0.036647
# C      0.038672
# GS     0.025390
# JPM    0.027667
# MS     0.037819
# WFC    0.030238
# dtype: float64

# %%
# Riskiest

df_risk[df_risk==df_risk.max()]
# Out:
# ticker
# C    0.038672
# dtype: float64

# %%
# Riskiest

df_risk[df_risk==df_risk.min()]
# Out:
# ticker
# GS    0.02539
# dtype: float64

# %% [markdown]
# <big>in the Year <b>2015</b></big>

# %%
df_risk_2015 = returns.loc['2015-01-01':'2016-01-01'].std()

df_risk_2015
# Out:
# ticker
# BAC    0.016163
# C      0.015289
# GS     0.014046
# JPM    0.014017
# MS     0.016249
# WFC    0.012591
# dtype: float64

# %%
# Riskiest

df_risk_2015[df_risk_2015==df_risk_2015.max()]
# Out:
# ticker
# MS    0.016249
# dtype: float64

# %%
# Riskiest

df_risk_2015[df_risk_2015==df_risk_2015.min()]
# Out:
# ticker
# WFC    0.012591
# dtype: float64

# %% [markdown]
# ## Plotting stock returns
# ___

# %%
sns.set_context('talk')

# %% [markdown]
# <big>Morgan Stanley (<b>MS</b>) for the year <b>2015</b>

# %%
returns_MS_2015 = returns.loc['2015-01-01':'2016-01-01', 'MS']

plt.figure(figsize=(12, 8))
sns.histplot(returns_MS_2015, kde=True, bins=50, color='green')
plt.xlabel('MS return')
# Out:
# Text(0.5, 0, 'MS return')

# %% [markdown]
# <big>CitiGroup (<b>C</b>) for the year <b>2008</b>

# %%
returns_c_2008 = returns.loc['2008-01-01':'2009-01-01', 'C']

plt.figure(figsize=(12, 8))
sns.histplot(returns_c_2008, kde=True, bins=50, color='red')
plt.xlabel('C return')
# Out:
# Text(0.5, 0, 'C return')

# %% [markdown]
# ## Moving Averages
# ___
#
# Let's analyze the moving averages for these stocks in the year <b>2008</b>.

# %% [markdown]
# ### Plot -  Close Price <code>vs</code> 30 day Rolling Average - BAC - 2008

# %%
plt.figure(figsize=(15, 5))

df_ = df.loc["2008-01-01" : "2009-01-01", ['BAC']]

df_['BAC'].plot(label='BAC Close')

df_['BAC'].rolling(window=30).mean().plot(label='30 day Rolling Avg.')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Correlation between the stocks Close Price
# ___

# %%
df.corr()
# Out:
# ticker       BAC         C        GS       JPM        MS       WFC
# ticker
# BAC     1.000000  0.971516  0.550898  0.103874  0.944218  0.008541
# C       0.971516  1.000000  0.434123  0.003515  0.933609 -0.068537
# GS      0.550898  0.434123  1.000000  0.685286  0.683792  0.499897
# JPM     0.103874  0.003515  0.685286  1.000000  0.250427  0.940269
# MS      0.944218  0.933609  0.683792  0.250427  1.000000  0.131834
# WFC     0.008541 -0.068537  0.499897  0.940269  0.131834  1.000000

# %%
plt.figure(figsize=(10,8))

sns.heatmap(data=df.corr(), annot=True)

plt.tight_layout()

# %%
plt.figure(figsize=(10,8))

sns.clustermap(data=df.corr(), annot=True)

plt.tight_layout()

# %% [markdown]
# ### Interactive Plots
# ___
#
# - <big><b>Candle Plot</b> - Bank of America <code>BAC</code> - year 2015</big>

# %%
bac_2015 = bank_stocks.xs('BAC', axis=0, level=1).loc['2015-01-01' : '2016-01-01']

bac_2015.head()
# Out:
#              High    Low   Open  Close       Volume  Adj Close
# Date
# 2015-01-02  18.03  17.68  17.99  17.90   48951100.0      15.88
# 2015-01-05  17.81  17.29  17.79  17.38  105605500.0      15.42
# 2015-01-06  17.44  16.78  17.42  16.86  144912400.0      14.96
# 2015-01-07  17.18  16.87  17.14  16.94  104603800.0      15.03
# 2015-01-08  17.34  17.10  17.16  17.29   73388500.0      15.34

# %%
bac_2015.tail()
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2015-12-24  17.38  17.22  17.32  17.27  29369400.0      15.51
# 2015-12-28  17.23  16.98  17.22  17.13  41777500.0      15.38
# 2015-12-29  17.35  17.16  17.25  17.28  45670400.0      15.52
# 2015-12-30  17.24  17.04  17.20  17.05  35066400.0      15.31
# 2015-12-31  17.07  16.83  17.01  16.83  47153000.0      15.11

# %%
bac_2015[['High', 'Low', 'Open', 'Close']].iplot(kind='candle')
# Out:
# <div>                            <div id="9860068a-a043-40ae-98a1-0e1aaa476052" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("9860068a-a043-40ae-98a1-0e1aaa476052")) {                    Plotly.newPlot(                        "9860068a-a043-40ae-98a1-0e1aaa476052",                        [{"close":[17.9,17.38,16.86,16.94,17.29,16.98,16.68,16.45,16.04,15.2,15.38,15.26,15.41,16.09,15.73,15.85,15.63,15.2,15.43,15.15,15.46,15.89,15.79,15.97,16.49,16.35,16.42,16.36,16.67,16.61,16.63,16.3,16.21,16.38,16.2,16.38,16.49,16.04,15.81,16.01,16.04,15.84,16.0,16.22,16.17,15.79,16.11,16.09,16.09,16.13,16.09,15.98,15.61,15.84,15.72,15.61,15.41,15.42,15.31,15.52,15.39,15.41,15.54,15.51,15.46,15.61,15.71,15.72,15.8,15.82,15.64,15.79,15.56,15.57,15.5,15.74,15.69,15.64,15.56,15.65,15.98,15.93,16.11,16.44,16.35,16.29,16.24,16.45,16.49,16.43,16.47,16.52,16.35,16.51,16.77,16.74,16.73,16.75,16.5,16.74,16.67,16.5,16.55,16.72,16.93,16.78,17.19,17.08,17.31,17.59,17.49,17.49,17.47,17.55,17.37,17.38,17.17,17.47,17.67,17.49,17.37,17.41,16.89,17.02,17.22,17.03,16.94,16.69,16.25,16.48,16.7,17.02,17.13,17.68,17.95,18.1,18.12,18.08,18.45,18.18,17.9,17.67,17.88,18.16,18.13,17.88,17.77,17.8,17.87,17.81,17.75,18.04,17.79,17.52,17.62,17.7,17.77,17.69,17.46,16.72,16.1,15.29,15.26,16.06,16.44,16.36,16.34,15.58,15.85,15.94,15.65,16.16,15.9,16.04,16.04,15.96,16.31,16.33,15.86,15.56,15.7,15.57,15.72,15.55,15.89,15.47,15.35,15.58,15.55,15.38,15.69,15.69,15.75,15.75,15.58,15.52,15.52,15.64,16.19,16.12,16.14,16.2,15.9,16.16,16.52,16.51,16.
# %% [markdown]
# - <big>SMA Plot - <b>Simple Moving Averages</b> - Morgan Stanley <code>MS</code> - year 2015</big>

# %%
ms_2015 = bank_stocks.xs('MS', axis=0, level=1).loc["2015-01-01" : "2016-01-01"]

ms_2015.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2015-01-02  39.15  38.25  39.05  38.71   7333800.0      33.13
# 2015-01-05  38.59  37.17  38.46  37.50  12507900.0      32.09
# 2015-01-06  37.54  36.06  37.47  36.42  16507800.0      31.17
# 2015-01-07  37.05  36.60  36.93  36.94   9957700.0      31.61
# 2015-01-08  37.76  37.29  37.29  37.49   8079600.0      32.08

# %%
ms_2015.tail()
# Out:
#              High    Low   Open  Close     Volume  Adj Close
# Date
# 2015-12-24  32.71  32.44  32.57  32.48  2798200.0      28.23
# 2015-12-28  32.36  31.95  32.36  32.17  5420300.0      27.96
# 2015-12-29  32.70  32.33  32.44  32.55  6388200.0      28.29
# 2015-12-30  32.65  32.20  32.50  32.23  5057200.0      28.01
# 2015-12-31  32.30  31.77  31.91  31.81  8154300.0      27.65

# %%
ms_2015['Close'].ta_plot(study='sma', periods=[13, 21, 55])    # TA_PLOT() - SMA
# Out:
# <div>                            <div id="dacb0640-6b71-46d0-9d15-73be4dd34871" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("dacb0640-6b71-46d0-9d15-73be4dd34871")) {                    Plotly.newPlot(                        "dacb0640-6b71-46d0-9d15-73be4dd34871",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Close","text":"","type":"scatter","x":["2015-01-02","2015-01-05","2015-01-06","2015-01-07","2015-01-08","2015-01-09","2015-01-12","2015-01-13","2015-01-14","2015-01-15","2015-01-16","2015-01-20","2015-01-21","2015-01-22","2015-01-23","2015-01-26","2015-01-27","2015-01-28","2015-01-29","2015-01-30","2015-02-02","2015-02-03","2015-02-04","2015-02-05","2015-02-06","2015-02-09","2015-02-10","2015-02-11","2015-02-12","2015-02-13","2015-02-17","2015-02-18","2015-02-19","2015-02-20","2015-02-23","2015-02-24","2015-02-25","2015-02-26","2015-02-27","2015-03-02","2015-03-03","2015-03-04","2015-03-05","2015-03-06","2015-03-09","2015-03-10","2015-03-11","2015-03-12","2015-03-13","2015-03-16","2015-03-17","2015-03-18","2015-03-19","2015-03-20","2015-03-23","2015-03-24","2015-03-25","2015-03-26","2015-03-27","2015-03-30","2015-03-31","2015-04-01","2015-04-02","2015-04-06","2015-04-07","2015-04-08","2015-04-09","2015-04-10","2015-04-13","2015-04-14","2015-04-15","2015-04-16","2015-04-17","2015-04-20","2015-04-21","2015-04-22","2015-04-23","2015-04-24","2015-04-27","2015-04-28","2015-04-29","2015-04-30","2015-05-01","2015-05-04","2015-05-05","2015-05-06","2015-05-07","2015-05-08","2015-05-11","2015-05-12","2015-05-13","2015-05-14","2015-05-15","2015-05-18","2015-05-19","2015-05-20","2015-05-21","2015-05-22","2015-05-26","2015-05-27","2015-05-28","2015-05-29","2015-06-01","2015-06-02","2015-06-03","2015-06-04","2015-06-05","2015-06-08","2015-06-09","2015-06-10","2015-06-11","2015-06-12","2015-06-15","2015-06-16","2015-06-17","2015-06-18","2015-06-19","2015-06-22","2015-06-23","2015-06-24","2015-06-25","2015-06-26","2015-06-29","2015-06-30","2015-07-01","2015-07-02","2015-07-06","2015-07-07","2015-07-08","2015-07-09","2015-07-10","2015-07-13","2015-07-14","2015-07-15","2015-07-16","2015-07-17","2015-07-20","2015-07-21","2015-07-22","2015-07-23","2015-07-24","2015-07-27","2015-07-28","2015-07-29","2015-07-30","2015-07-31","2015-08-03","2015-08-04","2015-08-05","2015-08-06","2015-08-07","2015-08-10","2015-08-11","2015-08-12","2015-08-13","2015-08-14","2015-08-17","2015-08-18","2015-08-19","2015-08-20","2015-08-21","2015-08-24","2015-08-25","2015-08-26","2015-08-27","2015-08-28","2015-08-31","2015-09-01","2015-09-02","2015-09-03","2015-09-04","2015-09-08","2015-09-09","2015-09-10","2015-09-11","2015-09-14","2015-09-15","2015-09-16","2015-09-17","2015-09-18","2015-09-21","2015-09-22","2015-09-23","2015-09-24","2015-09-25","2015-09-28","2015-09-29","2015-09-30","2015-10-01","2015-10-02","2015-10-05","2015-10-06","2015-10-07","2015-10-08","2015-10-09","2015-10-12","2015-10-13","2015-10-14","2015-10-15","2015-10-16","2015-10-19","2015-10-20","2015-10-21","2015-10-22","2015-10-23","2015-10-26","2015-10-27","2015-10-28","2015-10-29","2015-10-30","2015-11-02","2015-11-03","2015-11-04","2015-11-05","2015-11-06","2015-11-09","2015-11-10","2015-11-11","2015-11-12","2015-11-13","2015-11-16","2015-11-17","2015-11-18","2015-11-19","2015-11-20","2015-11-23","2015-11-24","2015-11-25","2015-11-27","2015-11-30","2015-12-01","2015-12-02","2015-12-03","2015-12-04","2015-12-07","2015-12-08","2015-12-09","2015-12-10","2015-12-11","2015-12-14","2015-12-15","2015-12-16","2015-12-17","2015-12-18","2015-12-21","2015-12-22","2015-12-23","2015-12-24","2015-12-28","2015-12-29","2015-12-30","2015-12-31"],"y":[38.71,37.5,36.42,36.94,37.49,36.88,36.37,36.03,35.21,34.58,34.89,34.75,34.73,35.53,35.15,35.11,34.66,33.77,34.37,33.81,34.42,35.04,34.77,34.93,35.79,35.63,36.16,36.37,36.9,36.78,36.92,36.37,36.33,36.74,36.27,36.74,36.59,36.06,35.79,36.24,35.82,35.09,35.52,35.53,35.67,34.88,3 ...

# %% [markdown]
# - <big><b>Bollinger Band Plot</b> - Bank of America <code>BAC</code> - year 2015</big>

# %%
bac_2015['Close'].ta_plot(study='boll')    # # TA_PLOT() - BOLL
# Out:
# <div>                            <div id="fea6361e-5b13-4970-a925-673a7f796936" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("fea6361e-5b13-4970-a925-673a7f796936")) {                    Plotly.newPlot(                        "fea6361e-5b13-4970-a925-673a7f796936",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Close","text":"","type":"scatter","x":["2015-01-02","2015-01-05","2015-01-06","2015-01-07","2015-01-08","2015-01-09","2015-01-12","2015-01-13","2015-01-14","2015-01-15","2015-01-16","2015-01-20","2015-01-21","2015-01-22","2015-01-23","2015-01-26","2015-01-27","2015-01-28","2015-01-29","2015-01-30","2015-02-02","2015-02-03","2015-02-04","2015-02-05","2015-02-06","2015-02-09","2015-02-10","2015-02-11","2015-02-12","2015-02-13","2015-02-17","2015-02-18","2015-02-19","2015-02-20","2015-02-23","2015-02-24","2015-02-25","2015-02-26","2015-02-27","2015-03-02","2015-03-03","2015-03-04","2015-03-05","2015-03-06","2015-03-09","2015-03-10","2015-03-11","2015-03-12","2015-03-13","2015-03-16","2015-03-17","2015-03-18","2015-03-19","2015-03-20","2015-03-23","2015-03-24","2015-03-25","2015-03-26","2015-03-27","2015-03-30","2015-03-31","2015-04-01","2015-04-02","2015-04-06","2015-04-07","2015-04-08","2015-04-09","2015-04-10","2015-04-13","2015-04-14","2015-04-15","2015-04-16","2015-04-17","2015-04-20","2015-04-21","2015-04-22","2015-04-23","2015-04-24","2015-04-27","2015-04-28","2015-04-29","2015-04-30","2015-05-01","2015-05-04","2015-05-05","2015-05-06","2015-05-07","2015-05-08","2015-05-11","2015-05-12","2015-05-13","2015-05-14","2015-05-15","2015-05-18","2015-05-19","2015-05-20","2015-05-21","2015-05-22","2015-05-26","2015-05-27","2015-05-28","2015-05-29","2015-06-01","2015-06-02","2015-06-03","2015-06-04","2015-06-05","2015-06-08","2015-06-09","2015-06-10","2015-06-11","2015-06-12","2015-06-15","2015-06-16","2015-06-17","2015-06-18","2015-06-19","2015-06-22","2015-06-23","2015-06-24","2015-06-25","2015-06-26","2015-06-29","2015-06-30","2015-07-01","2015-07-02","2015-07-06","2015-07-07","2015-07-08","2015-07-09","2015-07-10","2015-07-13","2015-07-14","2015-07-15","2015-07-16","2015-07-17","2015-07-20","2015-07-21","2015-07-22","2015-07-23","2015-07-24","2015-07-27","2015-07-28","2015-07-29","2015-07-30","2015-07-31","2015-08-03","2015-08-04","2015-08-05","2015-08-06","2015-08-07","2015-08-10","2015-08-11","2015-08-12","2015-08-13","2015-08-14","2015-08-17","2015-08-18","2015-08-19","2015-08-20","2015-08-21","2015-08-24","2015-08-25","2015-08-26","2015-08-27","2015-08-28","2015-08-31","2015-09-01","2015-09-02","2015-09-03","2015-09-04","2015-09-08","2015-09-09","2015-09-10","2015-09-11","2015-09-14","2015-09-15","2015-09-16","2015-09-17","2015-09-18","2015-09-21","2015-09-22","2015-09-23","2015-09-24","2015-09-25","2015-09-28","2015-09-29","2015-09-30","2015-10-01","2015-10-02","2015-10-05","2015-10-06","2015-10-07","2015-10-08","2015-10-09","2015-10-12","2015-10-13","2015-10-14","2015-10-15","2015-10-16","2015-10-19","2015-10-20","2015-10-21","2015-10-22","2015-10-23","2015-10-26","2015-10-27","2015-10-28","2015-10-29","2015-10-30","2015-11-02","2015-11-03","2015-11-04","2015-11-05","2015-11-06","2015-11-09","2015-11-10","2015-11-11","2015-11-12","2015-11-13","2015-11-16","2015-11-17","2015-11-18","2015-11-19","2015-11-20","2015-11-23","2015-11-24","2015-11-25","2015-11-27","2015-11-30","2015-12-01","2015-12-02","2015-12-03","2015-12-04","2015-12-07","2015-12-08","2015-12-09","2015-12-10","2015-12-11","2015-12-14","2015-12-15","2015-12-16","2015-12-17","2015-12-18","2015-12-21","2015-12-22","2015-12-23","2015-12-24","2015-12-28","2015-12-29","2015-12-30","2015-12-31"],"y":[17.9,17.38,16.86,16.94,17.29,16.98,16.68,16.45,16.04,15.2,15.38,15.26,15.41,16.09,15.73,15.85,15.63,15.2,15.43,15.15,15.46,15.89,15.79,15.97,16.49,16.35,16.42,16.36,16.67,16.61,16.63,16.3,16.21,16.38,16.2,16.38,16.49,16.04,15.81,16.01,16.04,15.84,16.0,16.22,16.17,15.79,16.11 ...
